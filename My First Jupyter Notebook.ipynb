# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Daniel Alhassan**
# Current Occupation: Graduate Student
# Desired Occupation: Data Scientist

# %% [markdown]
# *I am interested in data science as a career because, I love writing and working with data. At some point in my career I will also like to teach data science to others*

# %% [markdown]
# ### The code below will take x, which equals 5 and add it to 2.

# %%
x = 5; 
x + 2
# Out:
# 7

# %% [markdown]
# I am teaching a class this summer and only have five students namely
# 1. Dan
# 2. Dave
# 3. Sarah
# 4. Winston
# 5. Emily
#
# The following are lists of some of the things I need to get for my new apartment
# + Rice cooker
# + Study desk
# + Bed
# + Desk lamp
#
# My all-time favorite statistician and mentor, [Professor Bradley Efron](http://statweb.stanford.edu/~ckirby/brad/):
# ![Brad Efron](http://statweb.stanford.edu/~ckirby/brad/images/2014_Efron-outdoors.jpg)
